# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.tsa.seasonal as seasonal_decompose

# %%
# Generar datos
dates = df['Fecha']
values = df['Magnitud']
ts = pd.Series(values.values, index=dates)
print(dates)
print(values)
print(ts)

# %%
# Gráfica de la serie original
plt.figure(figsize=(10, 4))
plt.plot(ts, label='Serie Original')
plt.title('Serie Original')
plt.xlabel('Fecha')
plt.ylabel('Valor')
plt.legend()
plt.show()

# %%
# Descomposición de la serie de tiempo
from statsmodels.tsa.seasonal import seasonal_decompose # Import the function, not just the module
decomposition = seasonal_decompose(ts, model='additive')

# %%
# Gráfica de la serie original
plt.figure(figsize=(10, 6))
plt.subplot(411)
plt.plot(ts, label='Serie Original')
plt.title('Serie Original')
plt.xlabel('Fecha')
plt.ylabel('Valor')
plt.legend()
plt.show()

# Gráfica de tendencia
plt.subplot(412)
plt.plot(decomposition.trend, label='Tendencia')
plt.title('Tendencia')
plt.xlabel('Fecha')
plt.ylabel('Valor')
plt.legend()

# Gráfica de estacionalidad
plt.subplot(413)
plt.plot(decomposition.seasonal, label='Estacionalidad')
plt.title('Estacionalidad')
plt.xlabel('Fecha')
plt.ylabel('Valor')
plt.legend()

# Gráfica de residuo
plt.subplot(414)
plt.plot(decomposition.resid, label='Residuo')
plt.title('Residuo')
plt.xlabel('Fecha')
plt.ylabel('Valor')
plt.legend()

plt.tight_layout()
plt.show()
