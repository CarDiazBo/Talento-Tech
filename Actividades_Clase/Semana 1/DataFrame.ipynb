# %% [markdown]
# **Carlos Arturo Díaz Bonilla**
# 27/05/2024
# Ejercicio de creación de Data Frame

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Create a dataset if Chemical Elements of Rocks
value_Element_list = ['Zn', 'Au', 'Al','Be','Fe','Ca','Na','K','Mg','Si']
value_Isotope_list = [30,21,0.2,8,56,12,59,99,0.9,1.5] #Adimensional
value_Weight_list = [0.2,0.3,0.1,4.3,66,21,2.4,1.8,4.6,9.8] # [Klg/Mlg]
value_Concentration_list = [2,40,8,10,8,4,3,5,15,5] # [%]

# Dictionary ({key:value})
# with the format {"str":list}
data_dict = {"Element":value_Element_list,
             "Isotope":value_Isotope_list,
             "Weight":value_Weight_list,
             "Concentration":value_Concentration_list}

#print(data_dict)

# Turn a dictionary into a dataframe
df = pd.DataFrame(data_dict)

print(df)

# prompt: Con DataFrame df: add another column

df['Value'] = df['Weight'] * (df['Concentration'])
df
# Out:
#   Element  Isotope  Weight  Concentration
# 0      Zn     30.0     0.2              2
# 1      Au     21.0     0.3             40
# 2      Al      0.2     0.1              8
# 3      Be      8.0     4.3             10
# 4      Fe     56.0    66.0              8
# 5      Ca     12.0    21.0              4
# 6      Na     59.0     2.4              3
# 7       K     99.0     1.8              5
# 8      Mg      0.9     4.6             15
# 9      Si      1.5     9.8              5
#   Element  Isotope  Weight  Concentration  Value
# 0      Zn     30.0     0.2              2    0.4
# 1      Au     21.0     0.3             40   12.0
# 2      Al      0.2     0.1              8    0.8
# 3      Be      8.0     4.3             10   43.0
# 4      Fe     56.0    66.0              8  528.0
# 5      Ca     12.0    21.0              4   84.0
# 6      Na     59.0     2.4              3    7.2
# 7       K     99.0     1.8              5    9.0
# 8      Mg      0.9     4.6             15   69.0
# ...

# %%
df
# Out:
#   Element  Isotope  Weight  Concentration  Value
# 0      Zn     30.0     0.2              2    0.4
# 1      Au     21.0     0.3             40   12.0
# 2      Al      0.2     0.1              8    0.8
# 3      Be      8.0     4.3             10   43.0
# 4      Fe     56.0    66.0              8  528.0
# 5      Ca     12.0    21.0              4   84.0
# 6      Na     59.0     2.4              3    7.2
# 7       K     99.0     1.8              5    9.0
# 8      Mg      0.9     4.6             15   69.0
# 9      Si      1.5     9.8              5   49.0

# %%
df
# Out:
#   Element  Isotope  Weight  Concentration  Value
# 0      Zn     30.0     0.2              2    0.4
# 1      Au     21.0     0.3             40   12.0
# 2      Al      0.2     0.1              8    0.8
# 3      Be      8.0     4.3             10   43.0
# 4      Fe     56.0    66.0              8  528.0
# 5      Ca     12.0    21.0              4   84.0
# 6      Na     59.0     2.4              3    7.2
# 7       K     99.0     1.8              5    9.0
# 8      Mg      0.9     4.6             15   69.0
# 9      Si      1.5     9.8              5   49.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Isotope'].plot(kind='hist', bins=20, title='Isotope')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['Weight'].plot(kind='hist', bins=20, title='Weight')
# ...
